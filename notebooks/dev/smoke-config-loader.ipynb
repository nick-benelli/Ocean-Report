# %% [markdown]
# # Config Smoke Test Loader

# %%
from pathlib import Path
import getpass

# %%
from ocean_report.config.loader import (
    get_settings
)

# %%
username = getpass.getuser()

config_path = Path(rf"/Users/{username}/Workspace/repos/GitHub/Ocean-Report/config.yaml")

# %%
app_cfg = get_settings(config_path)

# %%
app_cfg.email.model_dump()
# Out:
# {'smtp_server': 'smtp.gmail.com',
#  'smtp_port': 587,
#  'sender': 'sender@gmail.com',
#  'password': 'app-password',
#  'recipients': 'recipient1@gmail.com,recipient2@gmail.com',
#  'test_recipients': 'friend1@example.com,friend2@example.com',
#  'recipient_urls': {'main': 'https://gist.githubusercontent.com/nick-benelli/88accfcfb52eac41217e88b24b0c4ef9/raw/lbi-ocean-report-recipients.txt',
#   'test': 'https://gist.github.com/nick-benelli/027c74299afc2976e7800d6d84c741ba/raw/lbi-ocean-test-recipients.txt',
#   'offseason': 'https://gist.githubusercontent.com/nick-benelli/e3f1eb031e5b443865c3a3b5e5cc5e97/raw/ocean-report-offseason-recips.txt'}}
